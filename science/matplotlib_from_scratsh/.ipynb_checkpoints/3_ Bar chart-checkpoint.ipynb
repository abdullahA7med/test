# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# data set.

frutes = ['Apple','orange','Pannan','dragon frute','cocco']

available_quantity = [100,50,40,65,90]

# %%
plt.bar(frutes , available_quantity)
# Out:
# <BarContainer object of 5 artists>
